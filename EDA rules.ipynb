# %% [markdown]
# # EDA of any datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Various checks to perform

# %%
# 1. check missing values
'''df.isnull().sum() or df.isna().sum()'''
# Out:
# 'df.isnull().sum() or df.isna().sum()'

# %%
# 2. check duplicates
''' df.duplicated().sum()
    if df.duplicated() is True means there is duplicate in the data otherwise False.
'''
# Out:
# ' df.duplicated().sum()\n    if df.duplicated() is True means there is duplicate in the data otherwise False.\n'

# %%
# 3. check datatypes
''' df.info() 
    if datatype is object means it is a categorical feature(string) otherwise int.
'''
# Out:
# ' df.info() \n    if datatype is object means it is a categorical feature(string) otherwise int.\n'

# %%
# 4. check the number of unique values of each columns
''' df.nunique()
'''
# Out:
# ' df.nunique()\n'

# %%
# 5. check the statistics of the dataset
''' df.describe()
    it will descibe about count, mean, standard deviation, minimum, 25%, 50%, 75%, maximum.
'''
# Out:
# ' df.describe()\n    it will descibe about count, mean, standard deviation, minimum, 25%, 50%, 75%, maximum.\n'

# %%
# 6. explore more about the data
''' df.head(), df.tail(), df.shape()
'''
# Out:
# ' df.head(), df.tail(), df.shape()\n'

# %%
# to seprate numerical and categorical features in pandas dataframe
''' numerical_features = [features for features in df.columns if df[featues].dtype!='O']
    categorical_features = [features for features in df.columns if df[featues].dtype=='O']
'''
# Out:
# " numerical_features = [features for features in df.columns if df[featues].dtype!='O']\n    categorical_features = [features for features in df.columns if df[featues].dtype=='O']\n"

# %%
# Do additional visualization operation to see insights from it.
